# %% [markdown]
# # 配置环境

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sdv
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# # 差分隐私处理

# %% [markdown]
# ## Step 1 import packages

# %%
from DataSynthesizer.DataDescriber import DataDescriber
from DataSynthesizer.DataGenerator import DataGenerator
from DataSynthesizer.ModelInspector import ModelInspector
from DataSynthesizer.lib.utils import read_json_file, display_bayesian_network

# %% [markdown]
# ## Step 2 user-defined parameteres

# %%
# input dataset
file_name = "artificial-data"
input_data = "./data/" + file_name + ".csv"
# location of two output files
mode = 'correlated_attribute_mode'
description_file = f"./out/{mode}/" + file_name + "_synthetic_description.json"
synthetic_data = f"./out/{mode}/" + file_name + "_synthetic_data.csv"

input_data, description_file, synthetic_data
# Out:
# ('./data/artificial-data.csv',
#  './out/correlated_attribute_mode/artificial-data_synthetic_description.json',
#  './out/correlated_attribute_mode/artificial-data_synthetic_data.csv')

# %%
input_df = pd.read_csv(input_data)
input_df.head()
# Out:
#   class     a1     a2     a3     a4          a5          a6          a7  \
# 0     a  0.000  0.050  0.980  0.282  235.713339  313.695254  337.925634
# 1     a  0.025  0.068  0.974  0.418  150.630006  330.307022  636.557282
# 2     a  0.050  0.076  0.952  0.540  135.400660  252.077716  107.465876
# 3     a  0.075  0.086  0.932  0.650   92.679124  327.717086  401.085067
# 4     a  0.100  0.100  0.892  0.722  256.205880  300.080381  375.754596
#
#            a8          a9         a10         a11         a12         a13  \
# 0  202.052105   39.775271   36.564409  110.444858  184.263033  620.614970
# 1  202.185862  222.903697  103.262770   79.783847  200.966259  448.180755
# 2   76.427631  587.053832  413.246732  585.963244   42.042480  137.611137
# 3  147.909215  595.930170  435.960522  360.902793  151.118047  251.035987
# 4  209.338265  408.517237  371.387827  682.856045   44.197421  247.508260
#
#           a14
# 0  115.428241
# 1  215.902954
# 2  398.039160
# 3  245.134662
# 4  330.274738

# %%
input_df.shape
# Out:
# (160, 15)

# %%
# An attribute is categorical if its domain size is less than this threshold.
# Here modify the threshold to adapt to the domain size of "education" (which is 14 in input dataset).
threshold_value = 10

# specify categorical attributes
# categorical_attributes = {'education': True}
categorical_attributes = {'class': True}

# specify which attributes are candidate keys of input dataset.
# candidate_keys = {'ssn': True}
candidate_keys = {}

# A parameter in Differential Privacy. It roughly means that removing a row in the input dataset will not 
# change the probability of getting the same output more than a multiplicative difference of exp(epsilon).
# Increase epsilon value to reduce the injected noises. Set epsilon=0 to turn off differential privacy.
epsilon = 200

# The maximum number of parents in Bayesian network, i.e., the maximum number of incoming edges.
degree_of_bayesian_network = 1

# Number of tuples generated in synthetic dataset.
num_tuples_to_generate = input_df.shape[0] # Here input_df.shape[0] is the same as input dataset, but it can be set to another number.

# %% [markdown]
# ## Step 3 DataDescriber
#
# 1. Instantiate a DataDescriber.
# 2. Compute the statistics of the dataset.
# 3. Save dataset description to a file on local machine.

# %%
describer = DataDescriber(category_threshold=threshold_value)
describer.describe_dataset_in_correlated_attribute_mode(dataset_file=input_data, 
                                                        epsilon=epsilon, 
                                                        k=degree_of_bayesian_network,
                                                        attribute_to_is_categorical=categorical_attributes,
                                                        attribute_to_is_candidate_key=candidate_keys)
describer.save_dataset_description_to_file(description_file)
# Out:
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT a13
# Adding attribute a14
# Adding attribute a11
# Adding attribute a12
# Adding attribute a1
# Adding attribute a3
# Adding attribute a2
# Adding attribute a4
# Adding attribute a10
# Adding attribute a9
# Adding attribute a5
# Adding attribute a6
# Adding attribute a7
# Adding attribute a8
# Adding attribute class
# ========================== BN constructed ==========================

# %%
display_bayesian_network(describer.bayesian_network)
# Out:
# Constructed Bayesian network:
#     a14   has parents ['a13'].
#     a11   has parents ['a13'].
#     a12   has parents ['a11'].
#     a1    has parents ['a11'].
#     a3    has parents ['a1'].
#     a2    has parents ['a3'].
#     a4    has parents ['a3'].
#     a10   has parents ['a13'].
#     a9    has parents ['a10'].
#     a5    has parents ['a3'].
#     a6    has parents ['a5'].
#     a7    has parents ['a1'].
#     a8    has parents ['a7'].
#     class has parents ['a5'].

# %% [markdown]
# ## Step 4 generate synthetic dataset
#
# 1. Instantiate a DataGenerator.
# 2. Generate a synthetic dataset.
# 3. Save it to local machine.

# %%
generator = DataGenerator()
generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
generator.save_synthetic_data(synthetic_data)

# %% [markdown]
# ## Step 5 compare the statistics of input and sythetic data (optional)
#
# The synthetic data is already saved in a file by step 4. The ModelInspector is for a quick test on the similarity between input and synthetic datasets.
#
# ### 5.1 instantiate a ModelInspector.
#
# It needs input dataset, synthetic dataset, and attribute description.

# %%
input_df.head()
# Out:
#   class     a1     a2     a3     a4          a5          a6          a7  \
# 0     a  0.000  0.050  0.980  0.282  235.713339  313.695254  337.925634
# 1     a  0.025  0.068  0.974  0.418  150.630006  330.307022  636.557282
# 2     a  0.050  0.076  0.952  0.540  135.400660  252.077716  107.465876
# 3     a  0.075  0.086  0.932  0.650   92.679124  327.717086  401.085067
# 4     a  0.100  0.100  0.892  0.722  256.205880  300.080381  375.754596
#
#            a8          a9         a10         a11         a12         a13  \
# 0  202.052105   39.775271   36.564409  110.444858  184.263033  620.614970
# 1  202.185862  222.903697  103.262770   79.783847  200.966259  448.180755
# 2   76.427631  587.053832  413.246732  585.963244   42.042480  137.611137
# 3  147.909215  595.930170  435.960522  360.902793  151.118047  251.035987
# 4  209.338265  408.517237  371.387827  682.856045   44.197421  247.508260
#
#           a14
# 0  115.428241
# 1  215.902954
# 2  398.039160
# 3  245.134662
# 4  330.274738

# %%
synthetic_df = pd.read_csv(synthetic_data)
synthetic_df.head()
# Out:
#   class        a1        a2        a3        a4          a5          a6  \
# 0     c  0.869916  0.885144  0.213350  0.192781  377.879395   97.128078
# 1     a  0.329450  0.499793  0.740791  0.227935  286.614350  204.966845
# 2     b  0.556753  0.268404  0.679150  0.285030  565.256266  331.348826
# 3     b  0.110122  0.265511  0.767420  0.378122  591.208828  382.271395
# 4     d  0.951175  0.686287  0.066925  1.002645  372.604761  149.656141
#
#            a7          a8          a9         a10         a11         a12  \
# 0  360.793726  198.589637  366.577015  263.905788   -0.870499  181.763538
# 1  624.278294  201.130846  260.339264  246.324474  305.433156   36.498461
# 2   20.816214   78.732724  419.888580  295.524106   99.720246  221.901102
# 3   78.614020  109.872536   72.736438   65.515368  671.633377  225.859338
# 4   55.566568   74.884357  605.176582  431.591955  598.088942   94.800144
#
#           a13         a14
# 0  352.670442  253.887346
# 1  479.633483  150.080897
# 2  375.790650  235.066941
# 3  358.365331  281.123865
# 4  238.793763  267.208383

# %%
synthetic_df.columns
# Out:
# Index(['class', 'a1', 'a2', 'a3', 'a4', 'a5', 'a6', 'a7', 'a8', 'a9', 'a10',
#        'a11', 'a12', 'a13', 'a14'],
#       dtype='object')

# %%
# Read attribute description from the dataset description file.
attribute_description = read_json_file(description_file)['attribute_description']

inspector = ModelInspector(input_df, synthetic_df, attribute_description)

# %% [markdown]
# ### 5.2 compare histograms between input and synthetic datasets.

# %%
for attribute in synthetic_df.columns:
    print(attribute)
    inspector.compare_histograms(attribute)
# Out:
# class
# a1
# a2
# a3
# a4
# a5
# a6
# a7
# a8
# a9
# a10
# a11
# a12
# a13
# a14

# %% [markdown]
# ### 5.3 compare pairwise mutual information

# %%
inspector.mutual_information_heatmap()

# %% [markdown]
# # 其他种类可视化的比较

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharex=True, sharey=True, figsize=(14, 7))
ax = sns.scatterplot(data=input_df, x="a1", y="a2", hue='class', palette=dict(a=sns.color_palette()[0], b=sns.color_palette()[1], c=sns.color_palette()[2], d=sns.color_palette()[3]), ax=ax1)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax = sns.scatterplot(data=synthetic_df, x="a1", y="a2", hue='class', palette=dict(a=sns.color_palette()[0], b=sns.color_palette()[1], c=sns.color_palette()[2], d=sns.color_palette()[3]), ax=ax2)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharex=True, sharey=True, figsize=(14, 7))
ax = sns.scatterplot(data=input_df, x="a1", y="a3", hue='class', palette=dict(a=sns.color_palette()[0], b=sns.color_palette()[1], c=sns.color_palette()[2], d=sns.color_palette()[3]), ax=ax1)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax = sns.scatterplot(data=synthetic_df, x="a1", y="a3", hue='class', palette=dict(a=sns.color_palette()[0], b=sns.color_palette()[1], c=sns.color_palette()[2], d=sns.color_palette()[3]), ax=ax2)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharex=True, sharey=True, figsize=(14, 7))
ax = sns.scatterplot(data=input_df, x="a1", y="a4", hue='class', palette=dict(a=sns.color_palette()[0], b=sns.color_palette()[1], c=sns.color_palette()[2], d=sns.color_palette()[3]), ax=ax1)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax = sns.scatterplot(data=synthetic_df, x="a1", y="a4", hue='class', palette=dict(a=sns.color_palette()[0], b=sns.color_palette()[1], c=sns.color_palette()[2], d=sns.color_palette()[3]), ax=ax2)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharex=True, sharey=True, figsize=(14, 7))
ax = sns.scatterplot(data=input_df, x="a5", y="a6", hue='class', palette=dict(a=sns.color_palette()[0], b=sns.color_palette()[1], c=sns.color_palette()[2], d=sns.color_palette()[3]), ax=ax1)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax = sns.scatterplot(data=synthetic_df, x="a5", y="a6", hue='class', palette=dict(a=sns.color_palette()[0], b=sns.color_palette()[1], c=sns.color_palette()[2], d=sns.color_palette()[3]), ax=ax2)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharex=True, sharey=True, figsize=(14, 7))
ax = sns.scatterplot(data=input_df, x="a7", y="a8", hue='class', palette=dict(a=sns.color_palette()[0], b=sns.color_palette()[1], c=sns.color_palette()[2], d=sns.color_palette()[3]), ax=ax1)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax = sns.scatterplot(data=synthetic_df, x="a7", y="a8", hue='class', palette=dict(a=sns.color_palette()[0], b=sns.color_palette()[1], c=sns.color_palette()[2], d=sns.color_palette()[3]), ax=ax2)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharex=True, sharey=True, figsize=(14, 7))
ax = sns.scatterplot(data=input_df, x="a9", y="a10", hue='class', palette=dict(a=sns.color_palette()[0], b=sns.color_palette()[1], c=sns.color_palette()[2], d=sns.color_palette()[3]), ax=ax1)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax = sns.scatterplot(data=synthetic_df, x="a9", y="a10", hue='class', palette=dict(a=sns.color_palette()[0], b=sns.color_palette()[1], c=sns.color_palette()[2], d=sns.color_palette()[3]), ax=ax2)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharex=True, sharey=True, figsize=(14, 7))
ax = sns.scatterplot(data=input_df, x="a11", y="a12", hue='class', palette=dict(a=sns.color_palette()[0], b=sns.color_palette()[1], c=sns.color_palette()[2], d=sns.color_palette()[3]), ax=ax1)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax = sns.scatterplot(data=synthetic_df, x="a11", y="a12", hue='class', palette=dict(a=sns.color_palette()[0], b=sns.color_palette()[1], c=sns.color_palette()[2], d=sns.color_palette()[3]), ax=ax2)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharex=True, sharey=True, figsize=(14, 7))
ax = sns.scatterplot(data=input_df, x="a13", y="a14", hue='class', palette=dict(a=sns.color_palette()[0], b=sns.color_palette()[1], c=sns.color_palette()[2], d=sns.color_palette()[3]), ax=ax1)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax = sns.scatterplot(data=synthetic_df, x="a13", y="a14", hue='class', palette=dict(a=sns.color_palette()[0], b=sns.color_palette()[1], c=sns.color_palette()[2], d=sns.color_palette()[3]), ax=ax2)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
